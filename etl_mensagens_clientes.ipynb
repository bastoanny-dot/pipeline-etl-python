# %%
conteudo = """Nome,Conta,Cartao
Barbara,67890,Gold
Andre,54321,Black
Anny,11223,Platinum
"""

with open("clientes.csv", "w") as arquivo:
    arquivo.write(conteudo)

print("Arquivo clientes.csv criado com sucesso!")
# Out:
# Arquivo clientes.csv criado com sucesso!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

df = pd.read_csv("clientes.csv")
df
# Out:
#       Nome  Conta    Cartao
# 0  Barbara  67890      Gold
# 1    Andre  54321     Black
# 2     Anny  11223  Platinum

# %%
def gerar_mensagem(nome, cartao):
    return f"Olá {nome}! Seu cartão {cartao} possui benefícios exclusivos."

df["Mensagem"] = df.apply(
    lambda row: gerar_mensagem(row["Nome"], row["Cartao"]),
    axis=1
)

df
# Out:
#       Nome  Conta    Cartao                                           Mensagem
# 0  Barbara  67890      Gold  Olá Barbara! Seu cartão Gold possui benefícios...
# 1    Andre  54321     Black  Olá Andre! Seu cartão Black possui benefícios ...
# 2     Anny  11223  Platinum  Olá Anny! Seu cartão Platinum possui benefício...

# %%
df.to_csv("clientes_com_mensagens.csv", index=False)
print("Arquivo final gerado com sucesso!")
# Out:
# Arquivo final gerado com sucesso!
